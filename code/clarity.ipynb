# %% [markdown]
# # Clarity Air Monitors

# %% [markdown]
# 1. Locations of Clarity air monitors in SSF and San Bruno
# 2. PM2.5 and NO2 metrics for Clarity air monitors during 2024-2025
#
# Imports:

# %%
import requests
import folium
import pandas as pd
import geopandas as gpd
import numpy as np
import plotly.express as px
import networkx as nx

# %% [markdown]
# ### Locations of Clarity Air Monitors

# %%
# Read data
clarity_df = pd.read_csv("../data/risesouthcity_clarity_24hmean_cleaned.csv")

clarity_df.head()
# Out:
#   Datasource.ID        Date  PM2.5.Mean.Mass.Concentration  \
# 0     DVRGV9737  2025-01-01                          20.41
# 1     DEVPF7186  2025-01-01                          24.12
# 2     DUBTA4581  2025-01-01                          15.27
# 3     DJTYV8538  2025-01-01                           8.93
# 4     DRYLF3821  2025-01-01                          28.47
#
#    NO2.Mean.Concentration  Temperature.Internal  Temperature.Ambient  \
# 0                    7.43                 10.37                  NaN
# 1                   11.91                 10.06                  NaN
# 2                     NaN                  9.40                  NaN
# 3                     NaN                 10.33                  NaN
# 4                    6.69                 10.07                  NaN
#
#    Rel.Humidity.Internal  Rel.Humidity.Ambient  Wind.Speed  Wind.Direction  \
# 0                  71.95                   NaN         NaN             NaN
# 1                  74.12                   NaN         NaN             NaN
# 2                  78.23                   NaN         NaN             NaN
# 3                  74.13                   NaN         NaN             NaN
# 4                  73.25                   NaN         NaN             NaN
#
#    Atmospheric.Pressure  Latitude  Longitude             Location
# 0                   NaN  37.66409 -122.40165        Gardiner Park
# 1                   NaN  37.65721 -122.41898  Evelin Pacheco Home
# 2                   NaN  37.62428 -122.45347   Portola Elementary
# 3                   NaN  37.61580 -122.41844      Parkside Middle
# 4                   NaN  37.65783 -122.40707   Marita Santos Home

# %%
# Analysis of missing values
na_pm = clarity_df['PM2.5.Mean.Mass.Concentration'].isnull().sum()
na_no2 = clarity_df['NO2.Mean.Concentration'].isnull().sum()
na_temp_int = clarity_df['Temperature.Internal'].isnull().sum()
na_temp_amb = clarity_df['Temperature.Ambient'].isnull().sum()
na_rel_hum_int = clarity_df['Rel.Humidity.Internal'].isnull().sum()
na_rel_hum_amb = clarity_df['Rel.Humidity.Ambient'].isnull().sum()
na_wind_speed = clarity_df['Wind.Speed'].isnull().sum()
na_wind_dir = clarity_df['Wind.Direction'].isnull().sum()
na_atmos_pres = clarity_df['Atmospheric.Pressure'].isnull().sum()

print(f"Percentage of missing values in PM2.5: {na_pm / clarity_df.shape[0]}")
print(f"Percentage of missing values in NO2: {na_no2 / clarity_df.shape[0]}")
print(f"Percentage of missing values in internal temperature: {na_temp_int / clarity_df.shape[0]}")
print(f"Percentage of missing values in ambient temperature: {na_temp_amb / clarity_df.shape[0]}")
print(f"Percentage of missing values in internal relative humidity: {na_rel_hum_int / clarity_df.shape[0]}")
print(f"Percentage of missing values in ambient relative humidity: {na_rel_hum_amb / clarity_df.shape[0]}")
print(f"Percentage of missing values in wind speed: {na_wind_speed / clarity_df.shape[0]}")
print(f"Percentage of missing values in wind direction: {na_wind_dir / clarity_df.shape[0]}")
print(f"Percentage of missing values in atmospheric pressure: {na_atmos_pres / clarity_df.shape[0]}")
# Out:
# Percentage of missing values in PM2.5: 0.0
# Percentage of missing values in NO2: 0.22991347342398022
# Percentage of missing values in internal temperature: 0.0
# Percentage of missing values in ambient temperature: 1.0
# Percentage of missing values in internal relative humidity: 0.0
# Percentage of missing values in ambient relative humidity: 1.0
# Percentage of missing values in wind speed: 1.0
# Percentage of missing values in wind direction: 1.0
# Percentage of missing values in atmospheric pressure: 1.0

# %%
# Remove unnecessary columns
clarity_df = clarity_df.drop(columns=['Temperature.Ambient', 'Wind.Speed', 'Atmospheric.Pressure',
                                      'Wind.Direction', 'Rel.Humidity.Ambient'])

clarity_df.head()
# Out:
#   Datasource.ID        Date  PM2.5.Mean.Mass.Concentration  \
# 0     DVRGV9737  2025-01-01                          20.41
# 1     DEVPF7186  2025-01-01                          24.12
# 2     DUBTA4581  2025-01-01                          15.27
# 3     DJTYV8538  2025-01-01                           8.93
# 4     DRYLF3821  2025-01-01                          28.47
#
#    NO2.Mean.Concentration  Temperature.Internal  Rel.Humidity.Internal  \
# 0                    7.43                 10.37                  71.95
# 1                   11.91                 10.06                  74.12
# 2                     NaN                  9.40                  78.23
# 3                     NaN                 10.33                  74.13
# 4                    6.69                 10.07                  73.25
#
#    Latitude  Longitude             Location
# 0  37.66409 -122.40165        Gardiner Park
# 1  37.65721 -122.41898  Evelin Pacheco Home
# 2  37.62428 -122.45347   Portola Elementary
# 3  37.61580 -122.41844      Parkside Middle
# 4  37.65783 -122.40707   Marita Santos Home

# %%
# Remove duplicate locations
clarity_locations_df = clarity_df.drop_duplicates(subset=['Latitude', 'Longitude'])

# Create GeoDataFrame
clarity_gdf = gpd.GeoDataFrame(clarity_locations_df, 
                               geometry=gpd.points_from_xy(clarity_locations_df['Longitude'], clarity_locations_df['Latitude']))

# Create a map centered around the mean coordinates
m = folium.Map(location=[clarity_gdf.geometry.y.mean(), clarity_gdf.geometry.x.mean()], zoom_start=10)

# Add markers for each location
for i in range(0, clarity_gdf.shape[0]):
    folium.Marker(
        [clarity_gdf.iloc[i].geometry.y, clarity_gdf.iloc[i].geometry.x],
        popup=clarity_gdf.iloc[i]['Location']
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f94c33036df65d4cbf02c846e323d957 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f94c33036df65d4cbf02c846e323d957&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f94c33036df65d4cbf02c846e323d957 = L.map(
#                 &quot;map_f94c33036df65d4cbf02c846e323d957&quot;,
#                 {
#                     center: [37.64441571428575, 1.0150610510858574e-15],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_373b00736057f789d33eef507721da5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#             var marker_f62f66ab723d44c63799f9178ede49fd = L.marker(
#                 [37.66409, -122.40165],
#                 {}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#         var popup_004c641c5a4cb3322d057cf238b858a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17860563513b606fb4b42dd0e76826c8 = $(`&lt;div id=&quot;html_17860563513b606fb4b42dd0e76826c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gardiner Park&lt;/div&gt;`)[0];
#                 popup_004c641c5a4cb3322d057cf238b858a6.setContent(html_17860563513b606fb4b42dd0e76826c8);
#
#
#
#         marker_f62f66ab723d44c63799f9178ede49fd.bindPopup(popup_004c641c5a4cb3322d057cf238b858a6)
#         ;
#
#
#
#
#             var marker_6b75f1c0b9a5c9d2da4e4db408961b17 = L.marker(
#                 [37.65721, -122.41898],
#                 {}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#         var popup_3bf142ff030a7d5998db86bfff82fdb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e18eca97997c52217df813759a31777d = $(`&lt;div id=&quot;html_e18eca97997c52217df813759a31777d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Evelin Pacheco Home&lt;/div&gt;`)[0];
#                 popup_3bf142ff030a7d5998db86bfff82fdb7.setContent(html_e18eca97997c52217df813759a31777d);
#
#
#
#         marker_6b75f1c0b9a5c9d2da4e4db408961b17.bindPopup(popup_3bf142ff030a7d5998db86bfff82fdb7)
#         ;
#
#
#
#
#             var marker_340a965651aa7f4eaf61de81b21922d6 = L.marker(
#                 [37.62428, -122.45347],
#                 {}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#         var popup_742d562498a7aeb8d5b8b4f55393b079 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52fe3dd929963fbd7d6269b7ba1e3a37 = $(`&lt;div id=&quot;html_52fe3dd929963fbd7d6269b7ba1e3a37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Portola Elementary&lt;/div&gt;`)[0];
#                 popup_742d562498a7aeb8d5b8b4f55393b079.setContent(html_52fe3dd929963fbd7d6269b7ba1e3a37);
#
#
#
#         marker_340a965651aa7f4eaf61de81b21922d6.bindPopup(popup_742d562498a7aeb8d5b8b4f55393b079)
#         ;
#
#
#
#
#             var marker_c72827620acb13c8b7f37f78e1325a7a = L.marker(
#                 [37.6158, -122.41844],
#                 {}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#         var popup_c30fd576095359987538a4a69936a61a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cbc93ab160c523c849d480f2b64d203 = $(`&lt;div id=&quot;html_8cbc93ab160c523c849d480f2b64d203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parkside Middle&lt;/div&gt;`)[0];
#                 popup_c30fd576095359987538a4a69936a61a.setContent(html_8cbc93ab160c523c849d480f2b64d203);
#
#
#
#         marker_c72827620acb13c8b7f37f78e1325a7a.bindPopup(popup_c30fd576095359987538a4a69936a61a)
#         ;
#
#
#
#
#             var marker_1d12f1e1bc14e23bde80fb5a15b832e1 = L.marker(
#                 [37.65783, -122.40707],
#                 {}
#             ).addTo(map_f94c33036df65d4cbf02c846e323d957);
#
#
#         var popup_13e3e044bcd718baec9d238aeca16d7e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_64332103b8c3097cfa4fe0a248660946 = $(`&lt;div id=&quot;html_64332103b8c3097cfa4fe0a248660946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marita Santos Home&lt;/div&gt;`)[0];
#                 popup_13e3e044bcd718baec9d238aeca16d7e.setContent(html_64332103b8c3097cfa4fe0a248660946);
#
#
#
#         marker_1d12f1e1bc14e23bde80fb5a15b832e1.bindPopup(popup_13e3e044bcd718baec9d238aeca16d7e)
#         ;
#
#
#
#
#             var marker_4982a31175b67e14c8b61f8444aaf056 = L.marker(
#                 [3

# %% [markdown]
# ### PM2.5 and NO2 Levels from 1-24 to 1-25

# %% [markdown]
# #### Highway Locations

# %%
# Read uncleaned data and location names
clarity_unclean_df = pd.read_csv("../data/Hourly Clarity Data 1-24 to 1-25.csv")
locations_df = pd.read_csv("../data/risesouthcity_locations.csv")

clarity_unclean_df.head()
# Out:
#   datasourceId  sourceId    sourceType outputFrequency  \
# 0    DHSHV3008  AMMHPRJX  CLARITY_NODE            hour
# 1    DHSHV3008  AMMHPRJX  CLARITY_NODE            hour
# 2    DHSHV3008  AMMHPRJX  CLARITY_NODE            hour
# 3    DHSHV3008  AMMHPRJX  CLARITY_NODE            hour
# 4    DHSHV3008  AMMHPRJX  CLARITY_NODE            hour
#
#               startOfPeriod               endOfPeriod  locationLatitude  \
# 0  2024-10-30T17:00:00.000Z  2024-10-30T18:00:00.000Z          37.65544
# 1  2024-10-30T18:00:00.000Z  2024-10-30T19:00:00.000Z          37.65544
# 2  2024-10-30T19:00:00.000Z  2024-10-30T20:00:00.000Z          37.65544
# 3  2024-10-30T20:00:00.000Z  2024-10-30T21:00:00.000Z          37.65544
# 4  2024-10-30T21:00:00.000Z  2024-10-30T22:00:00.000Z          37.65544
#
#    locationLongitude  atmPressure1HourMean.raw  atmPressure1HourMean.status  \
# 0          122.41276                       NaN                          NaN
# 1          122.41276                       NaN                          NaN
# 2          122.41276                       NaN                          NaN
# 3          122.41276                       NaN                          NaN
# 4          122.41276                       NaN                          NaN
#
#    ...  temperatureAmbient1HourMean.value  temperatureInternal1HourMean.raw  \
# 0  ...                                NaN                             17.62
# 1  ...                                NaN                             19.62
# 2  ...                                NaN                             21.16
# 3  ...                                NaN                             21.36
# 4  ...                                NaN                             20.79
#
#    temperatureInternal1HourMean.status  temperatureInternal1HourMean.value  \
# 0                         sensor-ready                               17.62
# 1                         sensor-ready                               19.62
# 2                         sensor-ready                               21.16
# 3                         sensor-ready                               21.36
# 4                         sensor-ready                               20.79
#
#    windDirection1HourMean.raw  windDirection1HourMean.status  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    windDirection1HourMean.value  windSpeed1HourMean.raw  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    windSpeed1HourMean.status  windSpeed1HourMean.value
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
# [5 rows x 110 columns]

# %%
locations_df.head()
# Out:
#   Datasource ID                              Name
# 0     DHSHV3008            Rise South City Office
# 1     DJGNN5114  San Bruno School District Office
# 2     DVRGV9737                     Gardiner Park
# 3     DRCAC7970                  Belle Air School
# 4     DCVIM2201                    Brentwood Park

# %%
# Merge location names with uncleaned data
clarity_unclean_df = clarity_unclean_df.merge(locations_df, left_on="datasourceId", right_on="Datasource ID")

# Drop unnecessary columns
clarity_unclean_df = clarity_unclean_df.drop(columns=['datasourceId', 'Datasource ID'])

# Rename columns
clarity_unclean_df = clarity_unclean_df.rename(columns={'Name': 'Location'})

clarity_unclean_df.head()
# Out:
#    sourceId    sourceType outputFrequency             startOfPeriod  \
# 0  AMMHPRJX  CLARITY_NODE            hour  2024-10-30T17:00:00.000Z
# 1  AMMHPRJX  CLARITY_NODE            hour  2024-10-30T18:00:00.000Z
# 2  AMMHPRJX  CLARITY_NODE            hour  2024-10-30T19:00:00.000Z
# 3  AMMHPRJX  CLARITY_NODE            hour  2024-10-30T20:00:00.000Z
# 4  AMMHPRJX  CLARITY_NODE            hour  2024-10-30T21:00:00.000Z
#
#                 endOfPeriod  locationLatitude  locationLongitude  \
# 0  2024-10-30T18:00:00.000Z          37.65544          122.41276
# 1  2024-10-30T19:00:00.000Z          37.65544          122.41276
# 2  2024-10-30T20:00:00.000Z          37.65544          122.41276
# 3  2024-10-30T21:00:00.000Z          37.65544          122.41276
# 4  2024-10-30T22:00:00.000Z          37.65544          122.41276
#
#    atmPressure1HourMean.raw  atmPressure1HourMean.status  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    atmPressure1HourMean.value  ...  temperatureInternal1HourMean.raw  \
# 0                         NaN  ...                             17.62
# 1                         NaN  ...                             19.62
# 2                         NaN  ...                             21.16
# 3                         NaN  ...                             21.36
# 4                         NaN  ...                             20.79
#
#    temperatureInternal1HourMean.status  temperatureInternal1HourMean.value  \
# 0                         sensor-ready                               17.62
# 1                         sensor-ready                               19.62
# 2                         sensor-ready                               21.16
# 3                         sensor-ready                               21.36
# 4                         sensor-ready                               20.79
#
#    windDirection1HourMean.raw  windDirection1HourMean.status  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    windDirection1HourMean.value  windSpeed1HourMean.raw  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
#    windSpeed1HourMean.status  windSpeed1HourMean.value                Location
# 0                        NaN                       NaN  Rise South City Office
# 1                        NaN                       NaN  Rise South City Office
# 2                        NaN                       NaN  Rise South City Office
# 3                        NaN                       NaN  Rise South City Office
# 4                        NaN                       NaN  Rise South City Office
#
# [5 rows x 110 columns]

# %%
# Select columns with the pm2_5 in the name and filter
# Make sure to include location and timestamp columns
pm2_5_cols = clarity_unclean_df.filter(like='pm2_5', axis=1).columns
clarity_unclean_df = clarity_unclean_df[['Location', 'startOfPeriod', 'endOfPeriod'] + list(pm2_5_cols)]

clarity_unclean_df.head()
# Out:
#                  Location             startOfPeriod               endOfPeriod  \
# 0  Rise South City Office  2024-10-30T17:00:00.000Z  2024-10-30T18:00:00.000Z
# 1  Rise South City Office  2024-10-30T18:00:00.000Z  2024-10-30T19:00:00.000Z
# 2  Rise South City Office  2024-10-30T19:00:00.000Z  2024-10-30T20:00:00.000Z
# 3  Rise South City Office  2024-10-30T20:00:00.000Z  2024-10-30T21:00:00.000Z
# 4  Rise South City Office  2024-10-30T21:00:00.000Z  2024-10-30T22:00:00.000Z
#
#    pm2_5ConcMass1HourMean.raw pm2_5ConcMass1HourMean.status  \
# 0                       36.07              calibrated-ready
# 1                       33.93              calibrated-ready
# 2                       39.04              calibrated-ready
# 3                       29.80              calibrated-ready
# 4                       14.08              calibrated-ready
#
#    pm2_5ConcMass1HourMean.value  pm2_5ConcMass1HourMeanWaDwerAqi.raw  \
# 0                         25.65                                 36.0
# 1                         24.42                                 34.0
# 2                         33.93                                 39.0
# 3                         25.57                                 30.0
# 4                         12.74                                 14.0
#
#   pm2_5ConcMass1HourMeanWaDwerAqi.status  \
# 0                       calibrated-ready
# 1                       calibrated-ready
# 2                       calibrated-ready
# 3                       calibrated-ready
# 4                       calibrated-ready
#
#    pm2_5ConcMass1HourMeanWaDwerAqi.value  pm2_5ConcMass24HourRollingMean.raw  \
# 0                                   26.0                               68.34
# 1                                   24.0                               56.87
# 2                                   34.0                               52.41
# 3                                   26.0                               47.89
# 4                                   13.0                               42.25
#
#    ... pm2_5ConcMassNowcast.value  pm2_5ConcMassNowcastUsEpaAqi.raw  \
# 0  ...                      39.03                             152.0
# 1  ...                      30.68                             122.0
# 2  ...                      32.42                             115.0
# 3  ...                      28.88                             100.0
# 4  ...                      20.68                              80.0
#
#    pm2_5ConcMassNowcastUsEpaAqi.status pm2_5ConcMassNowcastUsEpaAqi.value  \
# 0                     calibrated-ready                              110.0
# 1                     calibrated-ready                               91.0
# 2                     calibrated-ready                               94.0
# 3                     calibrated-ready                               88.0
# 4                     calibrated-ready                               72.0
#
#    pm2_5ConcNum1HourMean.raw  pm2_5ConcNum1HourMean.status  \
# 0                      37.40                  sensor-ready
# 1                      40.56                  sensor-ready
# 2                      46.88                  sensor-ready
# 3                      34.23                  sensor-ready
# 4                      22.57                  sensor-ready
#
#   pm2_5ConcNum1HourMean.value  pm2_5ConcNum24HourRollingMean.raw  \
# 0                       37.40                              71.04
# 1                       40.56                              60.88
# 2                       46.88                              57.38
# 3                       34.23                              52.75
# 4                       22.57                              47.72
#
#    pm2_5ConcNum24HourRollingMean.status pm2_5ConcNum24HourRollingMean.value
# 0                          sensor-ready                               71.04
# 1                          sensor-ready                               60.88
# 2                          sensor-ready                               57.38
# 3                          sensor-ready                               52.75
# 4                          sensor-ready                               47.72
#
# [5 rows x 24 columns]

# %%
# Convert timesteam columns to datetime
clarity_unclean_df['startOfPeriod'] = pd.to_datetime(clarity_unclean_df['startOfPeriod'])

# Drop end of period column
clarity_unclean_df = clarity_unclean_df.drop(columns=['endOfPeriod'])

clarity_unclean_df.head()
# Out:
#                  Location             startOfPeriod  \
# 0  Rise South City Office 2024-10-30 17:00:00+00:00
# 1  Rise South City Office 2024-10-30 18:00:00+00:00
# 2  Rise South City Office 2024-10-30 19:00:00+00:00
# 3  Rise South City Office 2024-10-30 20:00:00+00:00
# 4  Rise South City Office 2024-10-30 21:00:00+00:00
#
#    pm2_5ConcMass1HourMean.raw pm2_5ConcMass1HourMean.status  \
# 0                       36.07              calibrated-ready
# 1                       33.93              calibrated-ready
# 2                       39.04              calibrated-ready
# 3                       29.80              calibrated-ready
# 4                       14.08              calibrated-ready
#
#    pm2_5ConcMass1HourMean.value  pm2_5ConcMass1HourMeanWaDwerAqi.raw  \
# 0                         25.65                                 36.0
# 1                         24.42                                 34.0
# 2                         33.93                                 39.0
# 3                         25.57                                 30.0
# 4                         12.74                                 14.0
#
#   pm2_5ConcMass1HourMeanWaDwerAqi.status  \
# 0                       calibrated-ready
# 1                       calibrated-ready
# 2                       calibrated-ready
# 3                       calibrated-ready
# 4                       calibrated-ready
#
#    pm2_5ConcMass1HourMeanWaDwerAqi.value  pm2_5ConcMass24HourRollingMean.raw  \
# 0                                   26.0                               68.34
# 1                                   24.0                               56.87
# 2                                   34.0                               52.41
# 3                                   26.0                               47.89
# 4                                   13.0                               42.25
#
#   pm2_5ConcMass24HourRollingMean.status  ...  pm2_5ConcMassNowcast.value  \
# 0                      calibrated-ready  ...                       39.03
# 1                      calibrated-ready  ...                       30.68
# 2                      calibrated-ready  ...                       32.42
# 3                      calibrated-ready  ...                       28.88
# 4                      calibrated-ready  ...                       20.68
#
#    pm2_5ConcMassNowcastUsEpaAqi.raw pm2_5ConcMassNowcastUsEpaAqi.status  \
# 0                             152.0                    calibrated-ready
# 1                             122.0                    calibrated-ready
# 2                             115.0                    calibrated-ready
# 3                             100.0                    calibrated-ready
# 4                              80.0                    calibrated-ready
#
#    pm2_5ConcMassNowcastUsEpaAqi.value  pm2_5ConcNum1HourMean.raw  \
# 0                               110.0                      37.40
# 1                                91.0                      40.56
# 2                                94.0                      46.88
# 3                                88.0                      34.23
# 4                                72.0                      22.57
#
#   pm2_5ConcNum1HourMean.status  pm2_5ConcNum1HourMean.value  \
# 0                 sensor-ready                        37.40
# 1                 sensor-ready                        40.56
# 2                 sensor-ready                        46.88
# 3                 sensor-ready                        34.23
# 4                 sensor-ready                        22.57
#
#    pm2_5ConcNum24HourRollingMean.raw pm2_5ConcNum24HourRollingMean.status  \
# 0                              71.04                         sensor-ready
# 1                              60.88                         sensor-ready
# 2                              57.38                         sensor-ready
# 3                              52.75                         sensor-ready
# 4                              47.72                         sensor-ready
#
#    pm2_5ConcNum24HourRollingMean.value
# 0                                71.04
# 1                                60.88
# 2                                57.38
# 3                                52.75
# 4                                47.72
#
# [5 rows x 23 columns]

# %%
# Extract month and year from the timestamp and convert to string
clarity_unclean_df['Month-Year'] = clarity_unclean_df['startOfPeriod'].dt.strftime('%m-%y')

# Define the correct order for 'Month-Year'
month_year_order = ['10-24', '11-24', '12-24', '01-25']

# Convert 'Month-Year' to a categorical type with the correct order
clarity_unclean_df['Month-Year'] = pd.Categorical(clarity_unclean_df['Month-Year'], categories=month_year_order, ordered=True)

# %%
# Clarity monitor location names close to highways
highway_locations = ["Gardiner Park", "Cypress and Pine Playlot", "Marita Santos Home", 
                     "Nora Alvarado Home", "Rise South City Office", "Belle Air School"]

# Filter data for locations close to highways
clarity_highway_df = clarity_unclean_df[clarity_unclean_df['Location'].isin(highway_locations)]

clarity_highway_df.head()
# Out:
#                  Location             startOfPeriod  \
# 0  Rise South City Office 2024-10-30 17:00:00+00:00
# 1  Rise South City Office 2024-10-30 18:00:00+00:00
# 2  Rise South City Office 2024-10-30 19:00:00+00:00
# 3  Rise South City Office 2024-10-30 20:00:00+00:00
# 4  Rise South City Office 2024-10-30 21:00:00+00:00
#
#    pm2_5ConcMass1HourMean.raw pm2_5ConcMass1HourMean.status  \
# 0                       36.07              calibrated-ready
# 1                       33.93              calibrated-ready
# 2                       39.04              calibrated-ready
# 3                       29.80              calibrated-ready
# 4                       14.08              calibrated-ready
#
#    pm2_5ConcMass1HourMean.value  pm2_5ConcMass1HourMeanWaDwerAqi.raw  \
# 0                         25.65                                 36.0
# 1                         24.42                                 34.0
# 2                         33.93                                 39.0
# 3                         25.57                                 30.0
# 4                         12.74                                 14.0
#
#   pm2_5ConcMass1HourMeanWaDwerAqi.status  \
# 0                       calibrated-ready
# 1                       calibrated-ready
# 2                       calibrated-ready
# 3                       calibrated-ready
# 4                       calibrated-ready
#
#    pm2_5ConcMass1HourMeanWaDwerAqi.value  pm2_5ConcMass24HourRollingMean.raw  \
# 0                                   26.0                               68.34
# 1                                   24.0                               56.87
# 2                                   34.0                               52.41
# 3                                   26.0                               47.89
# 4                                   13.0                               42.25
#
#   pm2_5ConcMass24HourRollingMean.status  ...  \
# 0                      calibrated-ready  ...
# 1                      calibrated-ready  ...
# 2                      calibrated-ready  ...
# 3                      calibrated-ready  ...
# 4                      calibrated-ready  ...
#
#    pm2_5ConcMassNowcastUsEpaAqi.raw  pm2_5ConcMassNowcastUsEpaAqi.status  \
# 0                             152.0                     calibrated-ready
# 1                             122.0                     calibrated-ready
# 2                             115.0                     calibrated-ready
# 3                             100.0                     calibrated-ready
# 4                              80.0                     calibrated-ready
#
#   pm2_5ConcMassNowcastUsEpaAqi.value  pm2_5ConcNum1HourMean.raw  \
# 0                              110.0                      37.40
# 1                               91.0                      40.56
# 2                               94.0                      46.88
# 3                               88.0                      34.23
# 4                               72.0                      22.57
#
#    pm2_5ConcNum1HourMean.status pm2_5ConcNum1HourMean.value  \
# 0                  sensor-ready                       37.40
# 1                  sensor-ready                       40.56
# 2                  sensor-ready                       46.88
# 3                  sensor-ready                       34.23
# 4                  sensor-ready                       22.57
#
#    pm2_5ConcNum24HourRollingMean.raw  pm2_5ConcNum24HourRollingMean.status  \
# 0                              71.04                          sensor-ready
# 1                              60.88                          sensor-ready
# 2                              57.38                          sensor-ready
# 3                              52.75                          sensor-ready
# 4                              47.72                          sensor-ready
#
#   pm2_5ConcNum24HourRollingMean.value  Month-Year
# 0                               71.04       10-24
# 1                               60.88       10-24
# 2                               57.38       10-24
# 3                               52.75       10-24
# 4                               47.72       10-24
#
# [5 rows x 24 columns]

# %%
# Aggregate data to monthly level
monthly_avg_pm2_5 = clarity_highway_df.groupby(['Month-Year', 'Location']).agg({'pm2_5ConcMass1HourMean.raw': 'mean'}).reset_index()

# Sort by month-year
monthly_avg_pm2_5 = monthly_avg_pm2_5.sort_values(by='Month-Year')

monthly_avg_pm2_5.head()
# Out:
# /var/folders/tc/ygtvb05s0279mq2rg4cgkqp00000gn/T/ipykernel_59293/1900859137.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Month-Year                  Location  pm2_5ConcMass1HourMean.raw
# 0      10-24          Belle Air School                    2.001667
# 1      10-24  Cypress and Pine Playlot                         NaN
# 2      10-24             Gardiner Park                         NaN
# 3      10-24        Marita Santos Home                    1.955000
# 4      10-24        Nora Alvarado Home                    1.565000

# %%
# Create line plot using Plotly
fig = px.line(
    monthly_avg_pm2_5,
    x='Month-Year', y='pm2_5ConcMass1HourMean.raw',
    color='Location', markers=True,
    title='Monthly Average PM2.5 Concentration by Location',
    labels={'Month-Year': 'Month-Year', 'pm2_5ConcMass1HourMean.raw': 'PM2.5 Mean Mass Concentration'}
)

fig.update_xaxes(tickangle=45)
fig.show()

# %%
# Aggregate data to daily level
daily_avg_pm2_5 = clarity_highway_df.groupby(['Location', clarity_highway_df['startOfPeriod'].dt.date]).agg({'pm2_5ConcMass1HourMean.raw': 'mean'}).reset_index()
daily_avg_pm2_5.rename(columns={'startOfPeriod': 'Date'}, inplace=True)

# Sort the DataFrame by 'Date'
daily_avg_pm2_5 = daily_avg_pm2_5.sort_values(by='Date')

# %%
# Create line plot using Plotly
fig = px.line(
    daily_avg_pm2_5,
    x='Date', y='pm2_5ConcMass1HourMean.raw',
    color='Location', markers=True,
    title='Daily Average PM2.5 Concentration for Locations Close to Highways',
    labels={'Date': 'Date', 'pm2_5ConcMass1HourMean.raw': 'PM2.5 Mean Mass Concentration'}
)

# Update output size of plot
fig.update_layout(width=800, height=500)  # Adjust width as needed

# Show plot and adjust axes
fig.update_xaxes(tickangle=45)
fig.show()

# %%
# Pivot for modeling and prediction
daily_avg_pm2_5_pivot = daily_avg_pm2_5.pivot(
    index="Date", columns="Location", values="pm2_5ConcMass1HourMean.raw"
)

# Drop all data points with no readings
daily_avg_pm2_5_pivot.dropna(inplace=True)

daily_avg_pm2_5_pivot.shape
# Out:
# (51, 6)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Set up plotting environment
sns.set(style="whitegrid")

# Initialize the figure for subplots
fig, axes = plt.subplots(nrows=len(daily_avg_pm2_5_pivot.columns), ncols=2, figsize=(15, len(daily_avg_pm2_5_pivot.columns)*5))

# Loop through each column (target variable) and perform regression
for idx, col in enumerate(daily_avg_pm2_5_pivot.columns):
    # Set target variable
    y = daily_avg_pm2_5_pivot[col]
    # Set predictors as all other columns
    X = daily_avg_pm2_5_pivot.drop(columns=[col])
    
    # Fit a linear regression model
    model = LinearRegression()
    model.fit(X, y)
    
    # Make predictions
    y_pred = model.predict(X)
    
    # Compute residuals and R-squared
    residuals = y - y_pred
    r2 = r2_score(y, y_pred)
    mse = mean_squared_error(y, y_pred)
    
    # Plot Actual vs Predicted
    axes[idx, 0].scatter(y, y_pred, color="blue", alpha=0.5)
    axes[idx, 0].plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='--')  # Ideal line
    axes[idx, 0].set_title(f"Actual vs Predicted ({col})")
    axes[idx, 0].set_xlabel("Actual")
    axes[idx, 0].set_ylabel("Predicted")
    
    # Plot Residuals
    axes[idx, 1].scatter(y_pred, residuals, color="green", alpha=0.5)
    axes[idx, 1].axhline(y=0, color="red", linestyle="--")  # Zero residual line
    axes[idx, 1].set_title(f"Residuals Plot ({col})")
    axes[idx, 1].set_xlabel("Predicted")
    axes[idx, 1].set_ylabel("Residuals")

# Adjust layout to make the plots more readable
plt.tight_layout()
plt.show()

# %%
# Make copy for future comparisons
clarity_comp_df = clarity_unclean_df.copy()

# New column separating highway locations from others
clarity_comp_df['is_highway'] = clarity_comp_df['Location'].isin(highway_locations)

# %%
# Aggregate data to monthly level
monthly_avg_pm2_5 = clarity_comp_df.groupby(['Month-Year', 'is_highway']).agg({'pm2_5ConcMass1HourMean.raw': 'mean'}).reset_index()

# Sort by month-year
monthly_avg_pm2_5 = monthly_avg_pm2_5.sort_values(by='Month-Year')

monthly_avg_pm2_5.head()
# Out:
# /var/folders/tc/ygtvb05s0279mq2rg4cgkqp00000gn/T/ipykernel_59293/23969892.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   Month-Year  is_highway  pm2_5ConcMass1HourMean.raw
# 0      10-24       False                    1.994000
# 1      10-24        True                    7.794082
# 2      11-24       False                    5.432038
# 3      11-24        True                    6.942297
# 4      12-24       False                   19.922952

# %%
# Create line plot using Plotly
fig = px.line(
    monthly_avg_pm2_5,
    x='Month-Year', y='pm2_5ConcMass1HourMean.raw',
    color='is_highway', markers=True,
    title='Monthly Average PM2.5 Concentration by Proximity to Highway',
    labels={'Month-Year': 'Month-Year', 'pm2_5ConcMass1HourMean.raw': 'PM2.5 Mean Mass Concentration'}
)

fig.update_xaxes(tickangle=45)
fig.show()

# %%
# Aggregate data to daily level
daily_avg_pm2_5 = clarity_comp_df.groupby(['is_highway', clarity_comp_df['startOfPeriod'].dt.date]).agg({'pm2_5ConcMass1HourMean.raw': 'mean'}).reset_index()
daily_avg_pm2_5.rename(columns={'startOfPeriod': 'Date'}, inplace=True)

# Sort the DataFrame by 'Date'
daily_avg_pm2_5 = daily_avg_pm2_5.sort_values(by='Date')

# %%
# Compute standard deviation for each Date and is_highway group
daily_avg_pm2_5["pm2_5_std"] = clarity_comp_df.groupby(["is_highway", clarity_comp_df['startOfPeriod'].dt.date])["pm2_5ConcMass1HourMean.raw"].transform("std")

# Fill NaN values with 0 (if needed)
daily_avg_pm2_5["pm2_5_std"] = daily_avg_pm2_5["pm2_5_std"].fillna(0)

# Compute count for each Data and is_highway group
daily_avg_pm2_5["count"] = clarity_comp_df.groupby(["is_highway", clarity_comp_df['startOfPeriod'].dt.date])["pm2_5ConcMass1HourMean.raw"].transform("count")

daily_avg_pm2_5.head()
# Out:
#     is_highway        Date  pm2_5ConcMass1HourMean.raw  pm2_5_std  count
# 63        True  2024-10-30                   22.468571   6.092648     42
# 64        True  2024-10-31                    5.348333   0.806322     30
# 0        False  2024-10-31                    1.994000  16.015714      7
# 1        False  2024-11-01                    5.537417  16.015714      7
# 65        True  2024-11-01                    7.253646   0.806322     30

# %%
# Compute 95% confidence intervals
z_score = 1.96  # For 95% confidence level
daily_avg_pm2_5["pm2_5_ci"] = z_score * (daily_avg_pm2_5["pm2_5_std"] / np.sqrt(daily_avg_pm2_5["count"]))

# Compute CI upper and lower bounds
daily_avg_pm2_5["pm2_5_upper"] = daily_avg_pm2_5["pm2_5ConcMass1HourMean.raw"] + daily_avg_pm2_5["pm2_5_ci"]
daily_avg_pm2_5["pm2_5_lower"] = daily_avg_pm2_5["pm2_5ConcMass1HourMean.raw"] - daily_avg_pm2_5["pm2_5_ci"]

daily_avg_pm2_5
# Out:
#      is_highway        Date  pm2_5ConcMass1HourMean.raw  pm2_5_std  count  \
# 63         True  2024-10-30                   22.468571   6.092648     42
# 64         True  2024-10-31                    5.348333   0.806322     30
# 0         False  2024-10-31                    1.994000  16.015714      7
# 1         False  2024-11-01                    5.537417  16.015714      7
# 65         True  2024-11-01                    7.253646   0.806322     30
# ..          ...         ...                         ...        ...    ...
# 124        True  2024-12-30                    4.690000   4.357573     96
# 125        True  2024-12-31                    6.671667   2.226693    120
# 61        False  2024-12-31                    5.289110   6.092648     42
# 62        False  2025-01-01                   15.248676   0.806322     30
# 126        True  2025-01-01                   26.215882   4.357573     96
#
#       pm2_5_ci  pm2_5_upper  pm2_5_lower
# 63    1.842627    24.311199    20.625944
# 64    0.288539     5.636872     5.059795
# 0    11.864607    13.858607    -9.870607
# 1    11.864607    17.402023    -6.327190
# 65    0.288539     7.542185     6.965107
# ..         ...          ...          ...
# 124   0.871696     5.561696     3.818304
# 125   0.398406     7.070073     6.273261
# 61    1.842627     7.131737     3.446482
# 62    0.288539    15.537215    14.960138
# 126   0.871696    27.087578    25.344186
#
# [127 rows x 8 columns]

# %%
import plotly.graph_objects as go

# Define color mapping for each is_highway category
color_map = {
    "Highway": "rgba(255, 99, 71, 0.2)",  # Tomato Red
    "Non-Highway": "rgba(70, 130, 180, 0.2)"  # Steel Blue
}

# Create the base line plot
fig = px.line(
    daily_avg_pm2_5,
    x='Date', y='pm2_5ConcMass1HourMean.raw',
    color='is_highway', markers=True,
    title='Daily Average PM2.5 Concentration by Proximity to Highway',
    labels={'Date': 'Date', 'pm2_5ConcMass1HourMean.raw': 'PM2.5 Mean Mass Concentration'}
)

# Add shaded area for uncertainty intervals with different colors
for highway_group in daily_avg_pm2_5["is_highway"].unique():
    df_group = daily_avg_pm2_5[daily_avg_pm2_5["is_highway"] == highway_group]
    
    fig.add_traces([
        go.Scatter(
            x=df_group["Date"],
            y=df_group["pm2_5_upper"],
            mode="lines",
            line=dict(width=0),
            showlegend=False
        ),
        go.Scatter(
            x=df_group["Date"],
            y=df_group["pm2_5_lower"],
            mode="lines",
            fill="tonexty",
            line=dict(width=0),
            fillcolor=color_map.get(highway_group, "rgba(100,100,100,0.2)"),  # Default gray if missing
            name=f"{highway_group} CI"
        )
    ])

# Adjust size of output plot
fig.update_layout(width=800, height=500)  # Adjust width as needed

fig.update_xaxes(tickangle=45)
fig.show()

# %%
# Census tracts for SSF
ssf_tracts = [
    '6001P',
    '6017',
    '6018P',
    '6018',
    '6019',
    '6019.01',
    '6019.02',
    '6020P',
    '6020.01',
    '6020.02',
    '6021',
    '6022',
    '6022.02',
    '6022.01',
    '6023P',
    '6024P',
    '6024',
    '6025',
    '6026',
    '6026.02',
    '6038.01',
    '6038.02',
    '6039',
    '6040',
    '6041.02P',
    '6041.03',
    '6041.04',
    '6042P'
]

# Census tracts for SB
sb_tracts = [
    '6023P',
    '6030P',
    '6035P',
    '6036P',
    '6037',
    '6038P',
    '6039P',
    '6040',
    '6041.01P',
    '6041.02P',
    '6042P',
    '6046P',
    '6135.01P'
]

other_tracts = [
    '6016.01',
    '6027',
    '6140',
    '6016.03',
    '6016.05'
]

tracts = ssf_tracts + sb_tracts + other_tracts

# Tracts in the shapefile don't contain 'P'
reformat = lambda tract: tract.replace('P', '')
tracts_reformatted = list(map(reformat, tracts))

# %%
import requests

# URL for PurpleAir API
url = (
    "https://api.purpleair.com/v1/sensors?fields=name%2C%20sensor_index%2C%20longitude"
    "%2C%20latitude%2C%20pm2.5%2C%20pm2.5_60minute%2C%20confidence%2C%20rssi&nwlat=37.664934"
    "&nwlng=-122.438679&selat=37.603488&selng=-122.380142"
      )

# Add API key to URL header
headers = {'X-API-Key': '07F29582-E02A-11EF-A3B4-42010A800010'}

# Get API response
response = requests.get(url, headers=headers)
data = response.json()

# Create a dataframe from the json response
df = pd.DataFrame(data['data'], columns=data['fields'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      15 data = response.json()
#      17 # Create a dataframe from the json response
# ---> 18 df = pd.DataFrame(data['data'], columns=data['fields'])
#      19 df.head()
#
# NameError: name 'pd' is not defined

# %%
import geopandas as gpd

# Create a GeoDataFrame from the DataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['longitude'], df['latitude'], crs='EPSG:4326'))
gdf.head()
# Out:
#    sensor_index                                 name  rssi   latitude  \
# 0         21427                          Grundy Park   -55  37.622585
# 1         35103  Downtown South San Francisco Inside   -58  37.656963
# 2         65711                         Commodore Dr   -56  37.633860
# 3         67419           Acacia And Crystal Springs   -65  37.618250
# 4         67553                                  SB1   -64  37.617794
#
#     longitude  confidence  pm2.5  pm2.5_60minute                     geometry
# 0 -122.420970         100    1.1             1.1  POINT (-122.42097 37.62258)
# 1 -122.416110          59    0.0             0.0  POINT (-122.41611 37.65696)
# 2 -122.423110         100    1.5             2.0  POINT (-122.42311 37.63386)
# 3 -122.413450         100    1.7             2.2  POINT (-122.41345 37.61825)
# 4 -122.412735          30    0.4             1.0  POINT (-122.41274 37.61779)

# %%
# Read your shapefile
census_tracts = gpd.read_file('../data/tl_2024_06_tract.shp')
census_tracts['NAME'] = census_tracts['NAME'].astype(str)

# %%
# Census tracts for SSF and SB
ssf_sb_tracts = census_tracts[(census_tracts['COUNTYFP'] == '081') & census_tracts['NAME'].isin(tracts_reformatted)]

# %%
# Plot the shapefile
ax = ssf_sb_tracts.plot(color='lightblue', edgecolor='black', figsize=(10, 10))

# Overlay the points from your GeoDataFrame
gdf.plot(ax=ax, marker='o', color='purple', markersize=25)
# Out:
# <Axes: >

# %%
# Retrieve history for each purple air monitor
sensor_ids = list(df['sensor_index'])

# Initialize an empty dataframe to hold all sensor data
all_sensor_data = pd.DataFrame()

# Base URL for API requests
base_url = "https://api.purpleair.com/v1/sensors/{}/history?start_timestamp=1727766000&end_timestamp=1738310400&average=60&fields=rssi%2C%20pm2.5_alt"

for sensor_id in sensor_ids:
    url = base_url.format(sensor_id)
    # Get API response
    response = requests.get(url, headers=headers)
    data = response.json()
    
    # Create a dataframe from the json response
    sensor_df = pd.DataFrame(data['data'], columns=data['fields'])

    # Add data to all sensor data frame
    all_sensor_data = pd.concat([all_sensor_data, sensor_df], ignore_index=True)

all_sensor_data.shape
# Out:
[1732615200, -71, 0.5], [1729695600, -73, 16.0], [1733029200, -74, 10.6], [1733090400, -75, 6.5], [1737673200, -75, 5.9], [1737637200, -77, 4.9], [1733205600, -75, 2.5], [1733256000, -76, 13.9], [1733529600, -77, 8.5], [1734516000, -76, 13.2], [1734271200, -74, 0.9], [1734242400, -75, 1.8], [1734282000, -75, 5.2], [1737885600, -76, 3.7], [1737903600, -76, 0.8], [1737918000, -75, 1.3], [1736391600, -76, 1.1], [1736449200, -76, 1.8], [1735556400, -81, 1.3], [1735531200, -84, 3.8], [1735574400, -79, 1.8], [1732093200, -71, 0.5], [1736730000, -76, 3.5], [1736726400, -76, 1.9], [1736791200, -76, 0.4], [1731859200, -71, 5.2], [1732158000, -68, 1.0] ...
# (61941, 3)

# %%
all_sensor_data.shape
# Out:
# (61941, 3)

# %%
all_sensor_data.head()
# Out:
#    time_stamp  rssi  pm2.5_alt
# 0  1736373600   -55        0.4
# 1  1736370000   -55        0.7
# 2  1736319600   -59        0.6
# 3  1736326800   -60        0.3
# 4  1736136000   -60        4.5

# %% [markdown]
# ## **Pull PurpleAir Data**

# %%
# URL for PurpleAir API
url = (
    "https://api.purpleair.com/v1/sensors?fields=name%2C%20sensor_index%2C%20longitude"
    "%2C%20latitude%2C%20pm2.5%2C%20pm2.5_60minute%2C%20confidence%2C%20rssi&nwlat=37.664934"
    "&nwlng=-122.438679&selat=37.603488&selng=-122.380142"
      )
# Add API key to URL header
headers = {'X-API-Key': '07F29582-E02A-11EF-A3B4-42010A800010'}

# Get API response
response = requests.get(url, headers=headers)
data = response.json()

# Create a dataframe from the json response
df = pd.DataFrame(data['data'], columns=data['fields'])
df.head()
# Out:
#    sensor_index                                 name  rssi   latitude  \
# 0         21427                          Grundy Park   -59  37.622585
# 1         35103  Downtown South San Francisco Inside   -62  37.656963
# 2         65711                         Commodore Dr   -68  37.633860
# 3         67419           Acacia And Crystal Springs   -63  37.618250
# 4         67553                                  SB1   -61  37.617794
#
#     longitude  confidence  pm2.5  pm2.5_60minute
# 0 -122.420970         100    2.3             1.8
# 1 -122.416110          77    0.1             0.4
# 2 -122.423110         100    4.7             4.4
# 3 -122.413450         100    2.6             2.7
# 4 -122.412735          30    1.2             0.6

# %%
# Retrieve history for each purple air monitor
sensor_ids = list(df['sensor_index'])
sensor_name = list(df['name'])

# Initialize an empty dataframe to hold all sensor data
all_sensor_data = pd.DataFrame()

# Base URL for API requests
base_url = ("https://api.purpleair.com/v1/sensors/{}/history?start_timestamp=1728716400&end_timestamp=1744268400"
            "&average=60&fields=pm2.5_atm%2C%20pm1.0_atm%2C%20pm10.0_atm%2C%20humidity%2C%20pressure%2C%20temperature")

for sensor_id in sensor_ids:
    url = base_url.format(sensor_id)
    # Get API response
    response = requests.get(url, headers=headers)
    data = response.json()
    
    # Create a dataframe from the json response
    sensor_df = pd.DataFrame(data['data'], columns=data['fields'])

    # Add sensor ID to the dataframe
    sensor_df['sensor_index'] = sensor_id
    sensor_df['sensor_name'] = sensor_name[sensor_ids.index(sensor_id)]

    # Add data to all sensor data frame
    all_sensor_data = pd.concat([all_sensor_data, sensor_df], ignore_index=True)

all_sensor_data.shape
# Out:
# (81454, 9)

# %%
all_sensor_data.head()
# Out:
#    time_stamp  humidity  temperature  pressure  pm1.0_atm  pm2.5_atm  \
# 0  1744243200    38.566       77.865  1017.291     0.7465     1.6245
# 1  1743876000    36.832       81.365  1023.731     1.0160     1.9560
# 2  1744200000    63.298       56.000  1018.155     0.2330     0.8960
# 3  1735092000    63.700       60.000  1020.175     0.2420     1.1065
# 4  1743984000    30.465       72.066  1019.378     0.1250     0.5950
#
#    pm10.0_atm  sensor_index  sensor_name
# 0      2.3390         21427  Grundy Park
# 1      2.6980         21427  Grundy Park
# 2      1.5225         21427  Grundy Park
# 3      1.9585         21427  Grundy Park
# 4      0.8570         21427  Grundy Park

# %%
# Join to gather longitude and latitude
all_sensor_data = all_sensor_data.merge(df[['sensor_index', 'longitude', 'latitude']], on='sensor_index')

all_sensor_data.head()
# Out:
#    time_stamp  humidity  temperature  pressure  pm1.0_atm  pm2.5_atm  \
# 0  1744243200    38.566       77.865  1017.291     0.7465     1.6245
# 1  1743876000    36.832       81.365  1023.731     1.0160     1.9560
# 2  1744200000    63.298       56.000  1018.155     0.2330     0.8960
# 3  1735092000    63.700       60.000  1020.175     0.2420     1.1065
# 4  1743984000    30.465       72.066  1019.378     0.1250     0.5950
#
#    pm10.0_atm  sensor_index  sensor_name  longitude   latitude
# 0      2.3390         21427  Grundy Park -122.42097  37.622585
# 1      2.6980         21427  Grundy Park -122.42097  37.622585
# 2      1.5225         21427  Grundy Park -122.42097  37.622585
# 3      1.9585         21427  Grundy Park -122.42097  37.622585
# 4      0.8570         21427  Grundy Park -122.42097  37.622585

# %%
# Convert UNIX timestamp to datetime
all_sensor_data['time_stamp'] = pd.to_datetime(all_sensor_data['time_stamp'], unit='s')
all_sensor_data['time_stamp'] = all_sensor_data['time_stamp'].dt.tz_localize('UTC').dt.tz_convert('America/Los_Angeles')

all_sensor_data.head()
# Out:
#                  time_stamp  humidity  temperature  pressure  pm1.0_atm  \
# 0 2025-04-09 17:00:00-07:00    38.566       77.865  1017.291     0.7465
# 1 2025-04-05 11:00:00-07:00    36.832       81.365  1023.731     1.0160
# 2 2025-04-09 05:00:00-07:00    63.298       56.000  1018.155     0.2330
# 3 2024-12-24 18:00:00-08:00    63.700       60.000  1020.175     0.2420
# 4 2025-04-06 17:00:00-07:00    30.465       72.066  1019.378     0.1250
#
#    pm2.5_atm  pm10.0_atm  sensor_index  sensor_name  longitude   latitude
# 0     1.6245      2.3390         21427  Grundy Park -122.42097  37.622585
# 1     1.9560      2.6980         21427  Grundy Park -122.42097  37.622585
# 2     0.8960      1.5225         21427  Grundy Park -122.42097  37.622585
# 3     1.1065      1.9585         21427  Grundy Park -122.42097  37.622585
# 4     0.5950      0.8570         21427  Grundy Park -122.42097  37.622585

# %%
# Write data to CSV
all_sensor_data.to_csv('../data/uncleaned_purple_air_sensor_data.csv', index=False)
